# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
bucket = "tkachenko-ml-dataset"
music_df = pd.read_csv(f"s3://{bucket}/train_music.csv")
music_df.head()
# Out:
#             id  target  device_type  manufacturer_category  os_category  \
# 0  48104912810       0            7                   1514            3
# 1   4851497268       0            4                    896           28
# 2   4877823097       0            7                    592            3
# 3   4830183791       0            7                   1756            3
# 4  48103940036       0            4                   1057           28
#
#    sim_count  tp_flag        lt  block_flag  days_exp  ...  \
# 0        1.0        0  0.496508           0     299.0  ...
# 1        1.0        0  0.881540           0     189.0  ...
# 2        2.0        0  0.811192           0     347.0  ...
# 3        2.0        0  0.928449           1     343.0  ...
# 4        1.0        0  0.578654           0     355.0  ...
#
#    service_5_count_m3  service_6_count_m3  service_7_cost_m3  \
# 0                 0.0                 0.0                NaN
# ...

# %%
print("Shape:", music_df.shape)
print("Rows:", music_df.shape[0])
print("Columns:", music_df.shape[1])
# Out:
# Shape: (70000, 461)
# Rows: 70000
# Columns: 461

# %%
music_df.dtypes.value_counts()
# Out:
# float64    452
# int64        9
# Name: count, dtype: int64

# %%
music_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Columns: 461 entries, id to service_9_flag_m3
# dtypes: float64(452), int64(9)
# memory usage: 246.2 MB

# %%
missing = music_df.isna().mean().sort_values(ascending=False)
missing.head(20)
# Out:
# count_url_category_13    0.992771
# count_url_category_15    0.987029
# count_app_3              0.986643
# vol_app_3                0.986643
# count_url_category_12    0.983129
# vol_app_11               0.977329
# count_app_11             0.977329
# count_app_13             0.973143
# vol_app_13               0.973143
# count_url_category_1     0.972186
# count_gift_type_4        0.969586
# rr_gift_type_4           0.969586
# count_app_16             0.967171
# vol_app_16               0.967171
# count_app_14             0.964086
# vol_app_14               0.964086
# count_url_category_11    0.948486
# service_9_flag_m3        0.947871
# service_9_flag_m1        0.945414
# service_9_flag_m2        0.945157
# dtype: float64

# %%
plt.figure(figsize=(10,6))
missing.head(20).plot(kind="barh")
plt.title("Top-20 features by missing rate")
plt.xlabel("Missing rate")
plt.tight_layout()
plt.show()

# %%
TARGET_COL = "target"
target_counts = df[TARGET_COL].value_counts()
target_share = df[TARGET_COL].value_counts(normalize=True)

print(target_counts)
print(target_share)
# Out:
# target
# 0    64699
# 1     5301
# Name: count, dtype: int64
# target
# 0    0.924271
# 1    0.075729
# Name: proportion, dtype: float64

# %%
plt.figure()
df[TARGET_COL].value_counts().sort_index().plot(kind="bar")
plt.title("Target Distribution")
plt.xlabel("Target (0=No subscription, 1=Subscription)")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %%
corr = music_df.corr(numeric_only=True)[TARGET_COL].drop(TARGET_COL)
corr_sorted = corr.abs().sort_values(ascending=False)

top_corr = corr_sorted.head(20)
top_corr
# Out:
# lt                    0.186401
# id                    0.154761
# content_count_m1      0.116450
# vol_app_11            0.112219
# content_count_m3      0.111245
# count_app_11          0.103440
# service_P_flag_m3     0.099962
# content_count_m2      0.094392
# count_gift_type_3     0.081626
# service_P_flag_m2     0.080735
# count_app_5           0.076582
# count_act_type_6      0.073582
# count_act_type_7      0.066916
# count_sms_source_5    0.066107
# count_gift_type_1     0.063975
# rr_gift_type_3        0.062174
# count_act_type_1      0.062009
# paym_count_m1         0.059475
# rr_act_type_8         0.059002
# data_type_2_m1        0.058852
# Name: target, dtype: float64

# %%
plt.figure(figsize=(10,6))
corr.loc[top_corr.index].sort_values(key=np.abs).plot(kind="barh")
plt.title("Top correlations with target")
plt.xlabel("Correlation with target")
plt.tight_layout()
plt.show()

# %%
candidate_cat = []
ID_COL = "id"
for c in music_df.columns:
    if c in [TARGET_COL, ID_COL]:
        continue
    if music_df[c].nunique() <= 30:
        candidate_cat.append((c, music_df[c].nunique()))

candidate_cat[:20]
# Out:
# [('device_type', 7),
#  ('os_category', 17),
#  ('sim_count', 3),
#  ('tp_flag', 2),
#  ('block_flag', 2),
#  ('service_1_flag', 2),
#  ('service_2_flag', 1),
#  ('service_3_flag', 2),
#  ('is_obl_center', 2),
#  ('is_my_vf', 2),
#  ('inact_days_count', 1),
#  ('count_sms_source_1', 10),
#  ('count_sms_source_2', 9),
#  ('count_sms_source_5', 11),
#  ('count_sms_source_14', 17),
#  ('rr_act_type_1', 10),
#  ('rr_act_type_3', 9),
#  ('rr_act_type_4', 5),
#  ('rr_act_type_6', 7),
#  ('rr_act_type_7', 1)]
